# %%
import pandas as pd
data = pd.read_csv('generated_data.csv')


label=[]
dropout=[]

for ind in data.index:
    count = float(0)
    if(data['orphan'][ind] == 0):
        if(data['social_category'][ind] < 4):
            count += 1
        if(data['minority_group'][ind] == 1 or data['minority_group'][ind] == 5):
            count += 1
        if(data['bpl_beneficiary'][ind] == 1):
            count += 1
        if(data['ews_group'][ind] == 1):
            count += 1
        if(data['cwsn'][ind] == 1):
            count += 1
        if(data['mother\'s_occupation'][ind] == 1):
            count += 1
        if(data['father\'s_occupation'][ind] == 1):
            count += 1
        if(data['mother\'s_qualification'][ind] == 0):
            count += 1
        if(data['father\'s_qualification'][ind] == 0):
            count += 1
        if(data['family_annual_income'][ind] < 1):
            count += 1
        if(data['debt'][ind] == 1):
            count += 1
        if(data['mental_issues'][ind] == 1):
            count += 1
        if(data['results_in_previous_year_type'][ind] == 3 or data['results_in_previous_year_type'][ind] == 2):
            count += 1
        if(data['status_in_previous_year'][ind] == 4):
            count += 1
        if(data['dropout_student'][ind] == 1):
            count += 1
    else:
        count += 3.5
        if(data['social_category'][ind] < 4):
            count += 1
        if(data['minority_group'][ind] == 1 or data['minority_group'][ind] == 5):
            count += 1
        if(data['bpl_beneficiary'][ind] == 1):
            count += 1
        if(data['ews_group'][ind] == 1):
            count += 1
        if(data['cwsn'][ind] == 1):
            count += 1
        if(data['mental_issues'][ind] == 1):
            count += 1
        if(data['results_in_previous_year_type'][ind] == 3 or data['results_in_previous_year_type'][ind] == 2):
            count += 1
        if(data['status_in_previous_year'][ind] == 4):
            count += 1
        if(data['dropout_student'][ind] == 1):
            count += 1
        
        
    label.append(count)
    
data['label']=label

for i in data['label']:
    dropout.append(0.0625*i)
data['dropout']=dropout

# %%
data
# Out:
#     orphan  social_category  minority_group  bpl_beneficiary  ews_group  cwsn  \
# 0        0                4               7                1          1     0
# 1        0                1               3                1          0     0
# 2        1                3               0                0          0     0
# 3        0                2               5                1          0     0
# 4        0                1               7                0          1     0
# ..     ...              ...             ...              ...        ...   ...
# 66       1                3               3                1          0     0
# 67       1                1               1                1          0     0
# 68       1                2               2                0          0     0
# 69       1                3               5                1          0     1
# 70       1                1               6                0          1     0
#
#     mother's_occupation  father's_occupation  mother's_qualification  \
# 0                     0                    1                       1
# 1                     0                    0                       2
# 2                     0                    0                       0
# 3                     1                    1                       3
# 4                     1                    1                       4
# ..                  ...                  ...                     ...
# 66                    0                    0                       0
# 67                    0                    0                       0
# 68                    0                    0                       0
# 69                    0                    0                       0
# 70                    0                    0                       0
#
#     father's_qualification  ...  debt  mental_issues  \
# 0                        3  ...     0              0
# 1                        2  ...     1              0
# 2                        0  ...     0              0
# 3                        2  ...     0              0
# 4                        5  ...     0              0
# ..                     ...  ...   ...            ...
# 66                       0  ...     0              0
# 67                       0  ...     0              0
# 68                       0  ...     0              0
# 69                       0  ...     0              0
# 70                       0  ...     0              0
#
#     results_in_previous_year_type  status_in_previous_year  dropout_student  \
# 0                               1                        1                0
# 1                               1                        2                0
# 2                               2                        1                1
# 3                               1                        0                0
# 4                               1                        1                0
# ..                            ...                      ...              ...
# 66                              1                        4                1
# 67                              4                        4                1
# 68                              4                        4                1
# 69                              4                        4                0
# 70                              1                        1                0
#
#     age_group  district  gender  label  dropout
# 0           0         1       0    3.0  0.18750
# 1           2         3       1    3.0  0.18750
# 2           3         4       1    6.5  0.40625
# 3           1         1       1    5.0  0.31250
# 4           4         2       0    4.0  0.25000
# ..        ...       ...     ...    ...      ...
# 66          4        14       0    7.5  0.46875
# 67          4        25       0    8.5  0.53125
# 68          4        26       0    6.5  0.40625
# 69          1        32       1    8.5  0.53125
# 70          4        14       1    5.5  0.34375
#
# [71 rows x 21 columns]

# %%
std=data['dropout'].std()
var=data['dropout'].std()
print("Std of dropout:-",str(std))
print("Var of droput:-",str(var))
# Out:
# Std of dropout:- 0.14312725971962537
# Var of droput:- 0.14312725971962537

# %%
from pandas import read_csv
from matplotlib import pyplot
print(data.head())
data.plot()
pyplot.show()
# Out:
#    orphan  social_category  minority_group  bpl_beneficiary  ews_group  cwsn  \
# 0       0                4               7                1          1     0
# 1       0                1               3                1          0     0
# 2       1                3               0                0          0     0
# 3       0                2               5                1          0     0
# 4       0                1               7                0          1     0
#
#    mother's_occupation  father's_occupation  mother's_qualification  \
# 0                    0                    1                       1
# 1                    0                    0                       2
# 2                    0                    0                       0
# 3                    1                    1                       3
# 4                    1                    1                       4
#
#    father's_qualification  ...  debt  mental_issues  \
# 0                       3  ...     0              0
# 1                       2  ...     1              0
# 2                       0  ...     0              0
# 3                       2  ...     0              0
# 4                       5  ...     0              0
#
#    results_in_previous_year_type  status_in_previous_year  dropout_student  \
# 0                              1                        1                0
# 1                              1                        2                0
# 2                              2                        1                1
# 3                              1                        0                0
# 4                              1                        1                0
#
#    age_group  district  gender  label  dropout
# 0          0         1       0    3.0  0.18750
# 1          2         3       1    3.0  0.18750
# 2          3         4       1    6.5  0.40625
# 3          1         1       1    5.0  0.31250
# 4          4         2       0    4.0  0.25000
#
# [5 rows x 21 columns]

# %%
import pandas as pd
import numpy as np
x = data["age_group"]
y = data["dropout"]
slope_intercept = np.polyfit(x,y,1)

print(slope_intercept)
for i in slope_intercept:
    print(i)
# Out:
# [0.0053599 0.3378077]
# 0.00535990133545947
# 0.3378077038070558

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-5,5,100)
y = 0.0053599*x+0.3378077
plt.plot(x, y, '-r', label='y = 0.0053599*x+0.3378077')
plt.title('Graph of y = 0.0053599*x+0.3378077')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')

X = data['age_group'].values
Y = data['dropout'].values
plt.scatter(X, Y)

plt.show()

# %%
import pandas as pd
import numpy as np
x = data["district"]
y = data["dropout"]
slope_intercept = np.polyfit(x,y,1)

m=slope_intercept[0]
b=slope_intercept[1]

import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-50,50,100)
y = m*x+b
plt.plot(x, y, '-r',label='y')
plt.title('graph')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()

X = data['district'].values
Y = data['dropout'].values
plt.scatter(X, Y)

plt.show()
