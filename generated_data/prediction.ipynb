# %%
import pandas as pd
data = pd.read_csv('ori.csv')

# %%
from pandas import read_csv
from matplotlib import pyplot
print(data.head())
data.plot()
pyplot.show()
# Out:
#       year   district    caste  dropout rate girls  dropout rate boy  \
# 0  2013-14  ahmedabad  general                8.02             12.34
# 1  2013-14  ahmedabad      obc               18.43             23.13
# 2  2013-14  ahmedabad       sc                0.00             10.65
# 3  2013-14  ahmedabad       st               24.31             10.94
# 4  2013-14  bhavnager  general                0.00              0.00
#
#    dropout rate general
# 0                 10.54
# 1                 21.40
# 2                  6.08
# 3                 16.57
# 4                  0.00
