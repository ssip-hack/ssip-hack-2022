# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("statewise__dataset_csv.csv")

# %%
data.shape
# Out:
# (110, 14)

# %%
data.head()
# Out:
#          state_ut     year primary_boys primary_girls upper_primary_boys  \
# 0   A & N Islands  2012-13         0.83          0.51               0.68
# 1   A & N Islands  2013-14         1.35          1.06               1.21
# 2   A & N Islands  2014-15         0.47          0.55               0.51
# 3  Andhra Pradesh  2012-13          3.3          3.05               3.18
# 4  Andhra Pradesh  2013-14         4.31          4.39               4.35
#
#   upper_primary_girls upper_primary_total secondary_boys secondary_girls  \
# 0      Uppe_r_Primary                1.09           1.23            5.57
# 1                  NR                1.54           0.51            8.36
# 2                1.44                1.95           1.69           11.47
# 3                3.21                3.51           3.36           12.21
# 4                3.46                4.12           3.78           11.95
#
#   secondary_total hr_secondary_boys hr_secondary_girls hr_secondary_total  \
# ...

# %%
data.describe()
# Out:
#              state_ut     year primary_boys primary_girls upper_primary_boys  \
# count             110      110          110           110                110
# unique             40        3           93            87                 87
# top     A & N Islands  2013-14           NR            NR                 NR
# freq                3       37           15            15                 17
#
#        upper_primary_girls upper_primary_total secondary_boys secondary_girls  \
# count                  110                 110            110             110
# unique                  91                  97             96             106
# top                     NR                  NR             NR              NR
# freq                    16                   8              9               4
#
#        secondary_total hr_secondary_boys hr_secondary_girls  \
# count              110               110                110
# unique             107               106                 81
# ...

# %%
data.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
