# %%
import pandas as pd
df = pd.read_csv('D:\\HENIL\\Internship\\New folder\\ori ml.csv')
df.head()
# Out:
#    year  district  cast  dropout_rate_girls  dropout_rate_boy  \
# 0  2013         1     1                8.02             12.34
# 1  2013         1     2               18.43             23.13
# 2  2013         1     3                0.00             10.65
# 3  2013         1     4               24.31             10.94
# 4  2013         2     1                0.00              0.00
#
#    dropout_rate_general
# 0                 10.54
# 1                 21.40
# 2                  6.08
# 3                 16.57
# 4                  0.00

# %%
X = df.drop( [ "dropout_rate_girls" ], axis = 1)
Y = df[ [ "dropout_rate_girls" ]]

# %%
import pandas as pd
data = pd.read_csv('ori.csv')

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [16,9]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ['year','dropout rate girls', 'dropout rate boy']
  
# Read a CSV file
df = pd.read_csv("ori.csv", usecols=columns)

# Plot the lines
df.set_index('year').plot()

plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
print("X axis shape : -->  " , X.shape) #matrix
print("Y axis shape : -->", Y.shape) #means vector
# Out:
# X axis shape : -->   (160, 5)
# Y axis shape : --> (160, 1)

# %%
from sklearn.model_selection import train_test_split               
X_train ,X_test , Y_train , Y_test  = train_test_split(X,Y, test_size= 0.2)
print( "shape of  X_train " , X_train.shape )
print( "shape of  Y_test " , X_test.shape )
print( "shape of  X_train " , Y_train.shape )
print( "shape of  Y_test " , Y_test.shape )
# Out:
# shape of  X_train  (128, 5)
# shape of  Y_test  (32, 5)
# shape of  X_train  (128, 1)
# shape of  Y_test  (32, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(X_train ,  Y_train )
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[ -0.15920867,   0.06565308,   0.22476899, -16.54853399,
#          27.95139721]])

# %%
lr.intercept_
# Out:
# array([18.5309375])

# %%
lr.predict([X_test[0 , :]])
# Out:
# array([[13.99039973]])
