# %%
import pandas as pd
o1 = pd.read_csv('gender_data_insert.csv')
o1
# Out:
#        orphan  social_category  minority_group  bpl_beneficiary  ews_group  \
# 0           0                3               4                0          0
# 1           0                2               1                1          0
# 2           0                3               1                0          0
# 3           0                1               6                0          0
# 4           0                1               2                0          0
# ...       ...              ...             ...              ...        ...
# 49995       1                1               4                0          1
# 49996       0                3               2                0          1
# 49997       0                2               4                0          1
# 49998       0                1               4                0          0
# 49999       0                1               6                1          0
#
# ...

# %%
a=[]
for index in range(0,50000):
    a.append(o1['age_group'][index])

# %%
fg=['3-6 year' , '6-8 year' , '8-11 year' , '11-14 year' , '14-18 year']
ff=[]
for i in age_list:

    if i==1:
        ff.append(fg[0])
    if i==2:
        ff.append(fg[1])
    if i==3:
        ff.append(fg[2])
    if i==4:
        ff.append(fg[3])
    if i==5:
        ff.append(fg[4])

# %%
print(len(ff))
# Out:
# 50000

# %%
o1['age']=ff

# %%
o1.head()
# Out:
#    orphan  social_category  minority_group  bpl_beneficiary  ews_group  cwsn  \
# 0       0                3               4                0          0     1
# 1       0                2               1                1          0     0
# 2       0                3               1                0          0     0
# 3       0                1               6                0          0     1
# 4       0                1               2                0          0     1
#
#    mother's_occupation  father's_occupation  mother's_qualification  \
# 0                    1                    0                       3
# 1                    0                    1                       5
# 2                    0                    0                       5
# 3                    0                    0                       3
# 4                    1                    0                       3
#
#    father's_qualification  ...  age_group  district  gender  lable (y)  \
# ...

# %%
import pandas as pd
o2 = pd.read_csv('gender_data_insert.csv')

a=[]
for index in range(0,50000):
    a.append(o2['district'][index])
    
fg=['3-6 year' , '6-8 year' , '8-11 year' , '11-14 year' , '14-18 year']
ff=[]
for i in age_list:

    if i==1:
        ff.append(fg[0])
    if i==2:
        ff.append(fg[1])
    if i==3:
        ff.append(fg[2])
    if i==4:
        ff.append(fg[3])
    if i==5:
        ff.append(fg[4])
        
o1['age']=ff

# %%
o1.to_csv('two_data_add.csv')
